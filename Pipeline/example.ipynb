# %%
import comics_lib as f
from pathlib import Path
import matplotlib.pyplot as plt

# %%
image = Path("generate_input/0019_jpg.rf.0b3de368698d2f066257fcf8dbe5a0a3.jpg")
plt.imshow(plt.imread(image))

# %%
f.generate_unit_balloons(image)
f.generate_unit_personagens(image)
# Out:
# 0: 640x640 6 General_speechs, 9 narration speechs, 199.7ms
# Speed: 16.6ms preprocess, 199.7ms inference, 783.4ms postprocess per image at shape (1, 3, 640, 640)
# Processed generate_input\0019_jpg.rf.0b3de368698d2f066257fcf8dbe5a0a3.jpg. Overlays saved to 'generate_output_balloons_unit\overlays', Detections saved to 'generate_output_balloons_unit\detections', and Masks saved to 'generate_output_balloons_unit\masks',and Speech balloons saved to 'speech_balloons' folder.
# Processed 10 images. Overlays saved to 'generate_output_balloons_unit\overlays', Detections saved to 'generate_output_balloons_unit\detections', and Masks saved to 'generate_output_balloons_unit\masks',and Speech balloons saved to 'speech_balloons' folder.
#
# 0: 640x640 3 Gambits, 3 Rogues, 186.8ms
# Speed: 14.3ms preprocess, 186.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Processed 10 images. Overlays saved to 'generate_output_personagens_unit\overlays', Detections saved to 'generate_output_personagens_unit\detections', and Masks saved to 'generate_output_personagens_unit\masks',and Speech personagens saved to 'personagens' folder.

# %%
print(f.generate_prob_unity_personagens(image))
print(f.generate_prob_unity_balloons(image))
# Out:
# 0: 640x640 3 Gambits, 3 Rogues, 171.2ms
# Speed: 0.0ms preprocess, 171.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [('Gambit', 0.9626712799072266), ('Rogue', 0.8989042639732361), ('Gambit', 0.8971293568611145), ('Rogue', 0.8743770122528076), ('Rogue', 0.6528254151344299), ('Gambit', 0.5458322763442993)]
#
# 0: 640x640 6 General_speechs, 9 narration speechs, 143.0ms
# Speed: 0.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# [('General_speech', 0.931032657623291), ('General_speech', 0.9248316884040833), ('General_speech', 0.9183467626571655), ('narration speech', 0.9130937457084656), ('General_speech', 0.8995915055274963), ('General_speech', 0.8889108300209045), ('General_speech', 0.8534629344940186), ('narration speech', 0.8372253775596619), ('narration speech', 0.8179895281791687), ('narration speech', 0.807451605796814), ('narration speech', 0.803909957408905), ('narration speech', 0.7624875903129578), ('narration speech', 0.5916758179664612), ('narration speech', 0.43081212043762207), ('narration speech', 0.3022388517856598)]

# %%
image2 = Path('bubble_10.png')
plt.imshow(plt.imread(image2))

# %%
direction = f.bubble_direction(image2)
print(direction)
# Out:
# [-65 -94]

# %%
print(f.extract_text(image2))
# Out:
# w. POINT ME IN
# THE DIRECTION
# OF THE NEWEST
# MUTANT.
